# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/crime/2021-04/2021-04-metropolitan-stop-and-search.csv")

# %%
allEthnicities = df['Officer-defined ethnicity'].unique()
fig,ax= plt.subplots(nrows=6,ncols=1,squeeze=True)

# %%
for i,ethnicity in enumerate(allEthnicities):
    ethDf=df[df['Officer-defined ethnicity']==ethnicity]
    ethName=(ethDf[0:1]['Officer-defined ethnicity'])
    ethSize=(ethDf.shape[0])
    ethDf['Outcome'].hist(ax=ax[i],fig=fig)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[127], line 5
#       3 ethName=(ethDf[0:1]['Officer-defined ethnicity'])
#       4 ethSize=(ethDf.shape[0])
# ----> 5 ethDf['Outcome'].hist(ax=ax[i],fig=fig)
#
# File ~/Projects/Python/LO/newDC2/.venv/lib/python3.12/site-packages/pandas/plotting/_core.py:129, in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#      62 """
#      63 Draw histogram of the input series using matplotlib.
#      64
#    (...)
#     126     >>> hist = ser.groupby(level=0).hist()
#     127 """
#     128 plot_backend = _get_plot_backend(backend)
# --> 129 return plot_backend.hist_series(
#     130     self,
#     131     by=by,
#     132     ax=ax,
#     133     grid=grid,
#     134     xlabelsize=xlabelsize,
#     135     xrot=xrot,
#     136     ylabelsize=ylabelsize,
# ...

# %%
fig
